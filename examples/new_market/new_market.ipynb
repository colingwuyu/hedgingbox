# %% [markdown]
# <a href="https://colab.research.google.com/github/colingwuyu/hedgingbox/blob/new_market/examples/new_market/new_market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install necessary dependencies.
# !pip install dm-acme
# !pip install dm-acme[reverb]
# !pip install dm-acme[tf]
# !pip install dm-acme[envs]
# !pip install QuantLib-Python
# Out:
# Requirement already satisfied: dm-acme in /usr/local/lib/python3.6/dist-packages (0.1.8)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from dm-acme) (7.0.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from dm-acme) (0.8.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from dm-acme) (0.1.5)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.6/dist-packages (from dm-acme) (1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dm-acme) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py->dm-acme) (1.15.0)
# Requirement already satisfied: dm-acme[reverb] in /usr/local/lib/python3.6/dist-packages (0.1.8)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.6/dist-packages (from dm-acme[reverb]) (1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from dm-acme[reverb]) (0.8.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from dm-acme[reverb]) (7.0.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from dm-acme[reverb]) (0.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dm-acme[reverb]) (1.18.5)
# Requirement already satisfied: dm-reverb-nightly==0.1.0.dev20200708; extra == "reverb" in /usr/local/lib/python3.6/dist-packages (from dm-acme[reverb]) (0.1.0.dev20200708)
# Requirement already satisfied: tf-nightly==2.4.0.dev20200708; extra == "reverb" in /usr/local/lib/python3.6/dist-packages (from dm-acme[reverb]) (2.4.0.dev20200708)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from dm-env->dm-acme[reverb]) (1.15.0)
# Requirement already satisfied: portpicker in /usr/local/lib/python3.6/dist-packages (from dm-reverb-nightly==0.1.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.3.1)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.1.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.4.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.6.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.31.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (3.3.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (0.3.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.12.1)
# Requirement already satisfied: tf-estimator-nightly in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (2.4.0.dev2020090901)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (2.10.0)
# Requirement already satisfied: tb-nightly<2.4.0a0,>=2.3.0a0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (2.3.0a20200722)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (3.12.4)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (0.2.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (0.35.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.17.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.7.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (49.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (0.2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (2.10)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "reverb"->dm-acme[reverb]) (3.1.0)
# Requirement already satisfied: dm-acme[tf] in /usr/local/lib/python3.6/dist-packages (0.1.8)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (7.0.0)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (1.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (0.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (1.18.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (0.8.1)
# Requirement already satisfied: tf-nightly==2.4.0.dev20200708; extra == "tf" in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (2.4.0.dev20200708)
# Requirement already satisfied: dm-sonnet; extra == "tf" in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (2.0.0)
# Requirement already satisfied: trfl; extra == "tf" in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (1.1.0)
# Requirement already satisfied: tfp-nightly==0.12.0.dev20200717; extra == "tf" in /usr/local/lib/python3.6/dist-packages (from dm-acme[tf]) (0.12.0.dev20200717)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from dm-env->dm-acme[tf]) (1.15.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (2.10.0)
# Requirement already satisfied: tf-estimator-nightly in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (2.4.0.dev2020090901)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (0.2.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (3.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.12.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (3.12.4)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (0.3.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (0.35.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.1.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.31.0)
# Requirement already satisfied: tb-nightly<2.4.0a0,>=2.3.0a0 in /usr/local/lib/python3.6/dist-packages (from tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (2.3.0a20200722)
# Requirement already satisfied: tabulate>=0.7.5 in /usr/local/lib/python3.6/dist-packages (from dm-sonnet; extra == "tf"->dm-acme[tf]) (0.8.7)
# Requirement already satisfied: cloudpickle==1.3 in /usr/local/lib/python3.6/dist-packages (from tfp-nightly==0.12.0.dev20200717; extra == "tf"->dm-acme[tf]) (1.3.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from tfp-nightly==0.12.0.dev20200717; extra == "tf"->dm-acme[tf]) (4.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (49.6.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.17.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (0.2.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.24.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly<2.4.0a0,>=2.3.0a0->tf-nightly==2.4.0.dev20200708; extra == "tf"->dm-acme[tf]) (3.1.0)
# Requirement already satisfied: dm-acme[envs] in /usr/local/lib/python3.6/dist-packages (0.1.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (0.8.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (7.0.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (0.1.5)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (1.18.5)
# Requirement already satisfied: bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs" from git+git://github.com/deepmind/bsuite.git#egg=bsuite in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (0.3.2)
# Requirement already satisfied: gym; extra == "envs" in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (0.17.2)
# Requirement already satisfied: dm-control; extra == "envs" in /usr/local/lib/python3.6/dist-packages (from dm-acme[envs]) (0.0.322773188)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py->dm-acme[envs]) (1.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (1.0.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (3.2.2)
# Requirement already satisfied: plotnine in /usr/local/lib/python3.6/dist-packages (from bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (0.6.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.6/dist-packages (from bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (1.4.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.6/dist-packages (from bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (0.16.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (from bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (1.1.0)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym; extra == "envs"->dm-acme[envs]) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym; extra == "envs"->dm-acme[envs]) (1.5.0)
# Requirement already satisfied: labmaze in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (1.0.3)
# Requirement already satisfied: pyopengl>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (3.1.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (49.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (3.12.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (2.4.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (2.23.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (1.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (2.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from dm-control; extra == "envs"->dm-acme[envs]) (4.2.6)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (2018.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (1.2.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (0.10.2)
# Requirement already satisfied: mizani>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (0.6.0)
# Requirement already satisfied: descartes>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (1.1.0)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (0.5.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (2.5)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (2.4.1)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->dm-control; extra == "envs"->dm-acme[envs]) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->dm-control; extra == "envs"->dm-acme[envs]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->dm-control; extra == "envs"->dm-acme[envs]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->dm-control; extra == "envs"->dm-acme[envs]) (3.0.4)
# Requirement already satisfied: palettable in /usr/local/lib/python3.6/dist-packages (from mizani>=0.6.0->plotnine->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (3.3.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->bsuite@ git+git://github.com/deepmind/bsuite.git#egg=bsuite ; extra == "envs"->dm-acme[envs]) (4.4.2)
# Requirement already satisfied: QuantLib-Python in /usr/local/lib/python3.6/dist-packages (1.18)
# Requirement already satisfied: QuantLib in /usr/local/lib/python3.6/dist-packages (from QuantLib-Python) (1.19)

# %%
#@title Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/3wGAf7JsNm__-PNif1Y1Gvl4ZiXc1g_xqFpIfbBhDgyRXzgdifqdXBs
# Mounted at /content/gdrive

# %%
#@title Update HedgingBox
import os
project_folder = '/content/Projects'
hb_source = os.path.join(project_folder, 'HedgingBox')
# %mkdir "$project_folder"
# %cd "$project_folder"
# !pwd
# !mkdir -p 'ACME Models/New_Market'
# !git clone https://github.com/colingwuyu/HedgingBox.git
# %cd HedgingBox
# !git fetch --all
# !git checkout -b new_market origin/new_market
# !git pull
import sys
sys.path.append(hb_source)
# Out:
# mkdir: cannot create directory ‘/content/Projects’: File exists
# /content/Projects
# /content/Projects
# fatal: destination path 'HedgingBox' already exists and is not an empty directory.
# /content/Projects/HedgingBox
# Fetching origin
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/colingwuyu/HedgingBox
#    045fe89..e210f26  new_market -> origin/new_market
# fatal: A branch named 'new_market' already exists.
# Updating 045fe89..e210f26
# Fast-forward
#  new_market.ipynb | 1157 ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 1157 insertions(+)
#  create mode 100644 new_market.ipynb

# %%
#@title Import Modules
import acme
import dm_env
from acme import specs
from acme import datasets
from acme import wrappers
from acme.utils.loggers.csv import CSVLogger
from acme.adders import reverb as adders
from acme.tf import savers as tf2_savers
from acme.tf import networks as tf2_networks
from acme import types
from acme.tf import utils as tf2_utils
from acme.tf.losses.distributional import l2_project

import sonnet as snt

import reverb
import trfl

import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Mapping, Sequence

import hb
from hb.market_env.market import Market
from hb.market_env.portfolio import Portfolio
from hb.instrument.instrument_factory import InstrumentFactory
from hb.market_env.rewardrules.pnl_reward import PnLReward
from hb.bots.d4pgbot.bot import D4PGBot
from hb.bots.greekbot.bot import GreekHedgeBot 
from hb.market_env.market_test import MarketTest
from hb.market_env.portfolio import Portfolio

from absl import flags

# %%
#@title Test Setups
environment_path = "/content/gdrive/My Drive/Projects/New Market/Markets/" #@param {type:"string"}
agent_path = "/content/gdrive/My Drive/Projects/New Market/Agents/" #@param {type:"string"}
market_name = "Regression_BSM" #@param {type:"string"}
portfolio_name = "3M Call" #@param {type:"string"}
transaction_cost = 0.005 #@param {type:"number"}
portfolio_name = str(transaction_cost*1_000) + "TC " + portfolio_name

# %%
#@title BSM Regression Environment
def set_up_regression_bsm_market():
  market = Market(reward_rule=PnLReward(),
                  risk_free_rate=0.02,
                  hedging_step_in_days=1,
                  vol_model='BSM',
                  name=market_name,
                  dir_=environment_path)
  # create instruments
  # --------------------------------------------
  # AMZN
  # --------------------------------------------
  amzn = InstrumentFactory.create(
      f'Stock AMZN 100 10 0 {transaction_cost*100}'
  )
  amzn.set_trading_limit(4.)
  otc_atm_1w_call = InstrumentFactory.create(
                          f'EuroOpt AMZN OTC 1W Call 100.10 30.0 5 (AMZN_OTC_1W_ATM_CALL)'
                      ).underlying(amzn)
  otc_atm_1m_call = InstrumentFactory.create(
                          f'EuroOpt AMZN OTC 4W Call 100.30 30.0 5 (AMZN_OTC_1M_ATM_CALL)'
                      ).underlying(amzn)
  otc_atm_3m_call = InstrumentFactory.create(
                          f'EuroOpt AMZN OTC 3M Call 100.50 30.0 5 (AMZN_OTC_3M_ATM_CALL)'
                      ).underlying(amzn)
  market.calibrate(underlying=amzn,
                    listed_options=otc_atm_3m_call)
  market.add_instruments([otc_atm_1w_call, otc_atm_1m_call, otc_atm_3m_call])
  return wrappers.SinglePrecisionWrapper(market)

# %%
#@title BSM SPX AMZN Environment
def set_up_bsm_market():
  market = Market(reward_rule=PnLReward(),
                  risk_free_rate=0.015,
                  hedging_step_in_days=1,
                  vol_model='BSM',
                  name=market_name,
                  dir_=environment_path)
  # create instruments
  # --------------------------------------------
  # AMZN
  # --------------------------------------------
  amzn = InstrumentFactory.create(
      'Stock AMZN 100 25 0 0.15'
  )
  amzn.set_trading_limit(1.5)
  otc_atm_1m_call = InstrumentFactory.create(
                          f'EuroOpt AMZN OTC 4W Call 100 39.84 5 (AMZN_OTC_1M_ATM_CALL)'
                      ).underlying(amzn)
  market.calibrate(underlying=amzn,
                    listed_options=otc_atm_1m_call)
  market.add_instruments([otc_atm_1m_call])    
  # --------------------------------------------
  # SPX
  # --------------------------------------------
  spx = InstrumentFactory.create(
      'Stock SPX 100 10 1.92 0.5'
  )
  spx.set_trading_limit(1.5)
  otc_atm_1m_call = InstrumentFactory.create(
                          f'EuroOpt SPX OTC 4W Call 100 25.77 3.5 (SPX_OTC_1M_ATM_CALL)'
                      ).underlying(spx)
  market.calibrate(underlying=spx,
                    listed_options=otc_atm_1m_call)
  market.add_instruments([otc_atm_1m_call])            
  return wrappers.SinglePrecisionWrapper(market)

# %%
#@title BSM Regression Environment Setup
initial_stock_holding = 5 #@param {type:"number"}
initial_call_holding = -10 #@param {type:"number"}
market = set_up_regression_bsm_market()
portfolio = Portfolio.make_portfolio(
            instruments=market.get_instruments([
                                                'AMZN',
                                                'AMZN_OTC_3M_ATM_CALL'
                                                ]),
            holdings=[initial_stock_holding, 
                      initial_call_holding],
            name=portfolio_name
        )
market.init_portfolio(portfolio)

# %%
def make_networks(
    action_spec: specs.BoundedArray,
    policy_layer_sizes: Sequence[int] = (256, 256, 256),
    critic_layer_sizes: Sequence[int] = (512, 512, 256),
    vmin: float = -150.,
    vmax: float = 150.,
    num_atoms: int = 51,
) -> Mapping[str, types.TensorTransformation]:
  """Creates networks used by the agent."""

  # Get total number of action dimensions from action spec.
  num_dimensions = np.prod(action_spec.shape, dtype=int)

  # Create the shared observation network; here simply a state-less operation.
  observation_network = tf2_utils.batch_concat

  # Create the policy network.
  policy_network = snt.Sequential([
      tf2_networks.LayerNormMLP(policy_layer_sizes, activate_final=True),
      tf2_networks.NearZeroInitializedLinear(num_dimensions),
      tf2_networks.TanhToSpec(action_spec),
  ])

  # Create the critic network.
  critic_network = snt.Sequential([
      # The multiplexer concatenates the observations/actions.
      tf2_networks.CriticMultiplexer(),
      tf2_networks.LayerNormMLP(critic_layer_sizes, activate_final=True),
      tf2_networks.DiscreteValuedHead(vmin, vmax, num_atoms),
  ])

  return {
      'policy': policy_network,
      'critic': critic_network,
      'observation': observation_network,
  }

# %%
#@title Create D4PG Hedging Bot
#@markdown ###Replay Buffer Param
batch_size =  256#@param {type:"integer"}
samples_per_insert =  32#@param {type:"integer"}
#@markdown ###Prediction Param
num_prediction_episodes =  1000#@param {type:"integer"}
train_episodes_per_pred =  1000#@param {type:"integer"}
model_name = market_name + "/" + portfolio_name
create_new_model = False #@param {type:"boolean"}
risk_obj_func = True #@param {type:"boolean"}
risk_obj_c = 1.5 #@param {type:"number"}
model_path = f"{agent_path}{model_name}/"
if not os.path.exists(model_path):
  os.makedirs(model_path)
model_chkpt = model_path + "checkpoint" 
if not os.path.exists(model_chkpt):
  os.makedirs(model_chkpt)
spec = specs.make_environment_spec(market)
d4pg_networks = make_networks(spec.actions)

d4pg_bot = D4PGBot(
    environment_spec=spec,
    policy_network=d4pg_networks['policy'],
    critic_network=d4pg_networks['critic'],
    risk_obj_func=risk_obj_func,
    risk_obj_c=risk_obj_c,
    batch_size=batch_size,
    samples_per_insert=samples_per_insert,
    pred_episode=num_prediction_episodes,
    observation_per_pred=train_episodes_per_pred,
    pred_dir=model_path,
    checkpoint_subpath=model_path,
    checkpoint_per_min=30.
    )
d4pg_bot._checkpointer.save(force=True)
# Out:
# WARNING:tensorflow:Entity <function _yield_value at 0x7f9ec927d378> appears to be a generator function. It will not be converted by AutoGraph.
# WARNING: Entity <function _yield_value at 0x7f9ec927d378> appears to be a generator function. It will not be converted by AutoGraph.
# True

# %%
#@title D4PG Bot Train & Prediction
d4pg_bot._actor._actor._adder.reset()
num_episodes =  train_episodes_per_pred + num_prediction_episodes
num_check_points =  20#@param {type:"integer"}
learning_rate =  1e-4#@param {type:"number"}
norm_sig = 0.3 #@param {type:"number"}
prediction = True #@param {type:"boolean"}

# update learning rate
d4pg_bot._learner._policy_optimizer.learning_rate = learning_rate
d4pg_bot._learner._critic_optimizer.learning_rate = learning_rate
# update exploration epsilon
d4pg_bot._actor._actor._policy_network = tf.function(
    snt.Sequential([
            d4pg_bot._learner._observation_network,
            d4pg_bot._learner._policy_network,
            tf2_networks.ClippedGaussian(norm_sig),
            tf2_networks.ClipToSpec(spec.actions),
        ])
)
d4pg_bot.set_pred_only(prediction)
if prediction:
  num_check_points = 1
# Try running the environment loop. We have no assertions here because all
# we care about is that the agent runs without raising any errors.
if num_episodes > 0:
  for i in range(num_check_points):
    print(f"Check Point {i}")
    # train
    loop = acme.EnvironmentLoop(market, d4pg_bot)
    if not prediction:
      market.set_pred_mode(False)
      loop.run(num_episodes=train_episodes_per_pred)
    # prediction
    market.set_pred_mode(True)
    market.set_pred_episodes(num_prediction_episodes)
    loop.run(num_episodes=market.get_pred_episodes())
# Out:
# Check Point 0
# [Environment Loop] Episode Length = 90 | Episode Return = -23.344 | Episodes = 4 | Steps = 360 | Steps Per Second = 515.990
# [Environment Loop] Episode Length = 90 | Episode Return = -7.949 | Episodes = 9 | Steps = 810 | Steps Per Second = 469.331
# [Environment Loop] Episode Length = 90 | Episode Return = -14.130 | Episodes = 15 | Steps = 1350 | Steps Per Second = 518.839
# [Environment Loop] Episode Length = 90 | Episode Return = -18.529 | Episodes = 21 | Steps = 1890 | Steps Per Second = 548.155
# [Environment Loop] Episode Length = 90 | Episode Return = -8.975 | Episodes = 26 | Steps = 2340 | Steps Per Second = 284.198
# [Environment Loop] Episode Length = 90 | Episode Return = -10.516 | Episodes = 32 | Steps = 2880 | Steps Per Second = 301.944
# [Environment Loop] Episode Length = 90 | Episode Return = -17.875 | Episodes = 38 | Steps = 3420 | Steps Per Second = 477.217
# [Environment Loop] Episode Length = 90 | Episode Return = -14.646 | Episodes = 44 | Steps = 3960 | Steps Per Second = 542.761
# [Environment Loop] Episode Length = 90 | Episode Return = -11.117 | Episodes = 50 | Steps = 4500 | Steps Per Second = 546.034
# [Environment Loop] Episode Length = 90 | Episode Return = -10.902 | Episodes = 56 | Steps = 5040 | Steps Per Second = 529.444
# [Environment Loop] Episode Length = 90 | Episode Return = -9.522 | Episodes = 62 | Steps = 5580 | Steps Per Second = 545.162
# [Environment Loop] Episode Length = 90 | Episode Return = -14.518 | Episodes = 67 | Steps = 6030 | Steps Per Second = 545.400
# [Environment Loop] Episode Length = 90 | Episode Return = -12.741 | Episodes = 73 | Steps = 6570 | Steps Per Second = 552.587
# [Environment Loop] Episode Length = 90 | Episode Return = -11.690 | Episodes = 79 | Steps = 7110 | Steps Per Second = 526.460
# [Environment Loop] Episode Length = 90 | Episode Return = -19.435 | Episodes = 85 | Steps = 7650 | Steps Per Second = 515.482
# [Environment Loop] Episode Length = 90 | Episode Return = -13.703 | Episodes = 91 | Steps = 8190 | Steps Per Second = 547.887
# [Environment Loop] Episode Length = 90 | Episode Return = -7.461 | Episodes = 97 | Steps = 8730 | Steps Per Second = 538.052
# [Environment Loop] Episode Length = 90 | Episode Return = -45.745 | Episodes = 103 | Steps = 9270 | Steps Per Second = 534.106
# [Environment Loop] Episode Length = 90 | Episode Return = -38.254 | Episodes = 109 | Steps = 9810 | Steps Per Second = 535.379
# [Environment Loop] Episode Length = 90 | Episode Return = -8.586 | Episodes = 115 | Steps = 10350 | Steps Per Second = 546.771
# [Environment Loop] Episode Length = 90 | Episode Return = -14.004 | Episodes = 120 | Steps = 10800 | Steps Per Second = 286.620
# [Environment Loop] Episode Length = 90 | Episode Return = -22.037 | Episodes = 126 | Steps = 11340 | Steps Per Second = 297.999
# [Environment Loop] Episode Length = 90 | Episode Return = -26.341 | Episodes = 132 | Steps = 11880 | Steps Per Second = 302.901
# [Environment Loop] Episode Length = 90 | Episode Return = -8.662 | Episodes = 138 | Steps = 12420 | Steps Per Second = 520.646
# [Environment Loop] Episode Length = 90 | Episode Return = -7.578 | Episodes = 143 | Steps = 12870 | Steps Per Second = 421.996
# [Environment Loop] Episode Length = 90 | Episode Return = -6.374 | Episodes = 148 | Steps = 13320 | Steps Per Second = 420.730
# [Environment Loop] Episode Length = 90 | Episode Return = -12.170 | Episodes = 153 | Steps = 13770 | Steps Per Second = 439.733
# [Environment Loop] Episode Length = 90 | Episode Return = -14.505 | Episodes = 158 | Steps = 14220 | Steps Per Second = 445.669
# [Environment Loop] Episode Length = 90 | Episode Return = -8.479 | Episodes = 163 | Steps = 14670 | Steps Per Second = 444.857
# [Environment Loop] Episode Length = 90 | Episode Return = -23.421 | Episodes = 167 | Steps = 15030 | Steps Per Second = 391.266
# [Environment Loop] Episode Length = 90 | Episode Return = -9.406 | Episodes = 172 | Steps = 15480 | Steps Per Second = 442.039
# [Environment Loop] Episode Length = 90 | Episode Return = 2.328 | Episodes = 177 | Steps = 15930 | Steps Per Second = 449.414
# [Environment Loop] Episode Length = 90 | Episode Return = -35.153 | Episodes = 182 | Steps = 16380 | Steps Per Second = 267.112
# [Environment Loop] Episode Length = 90 | Episode Return = -10.668 | Episodes = 188 | Steps = 16920 | Steps Per Second = 552.699
# [Environment Loop] Episode Length = 90 | Episode Return = -13.593 | Episodes = 194 | Steps = 17460 | Steps Per Second = 544.835
# [Environment Loop] Episode Length = 90 | Episode Return = -9.181 | Episodes = 200 | Steps = 18000 | Steps Per Second = 516.816
# [Environment Loop] Episode Length = 90 | Episode Return = -16.815 | Episodes = 206 | Steps = 18540 | Steps Per Second = 530.834
# [Environment Loop] Episode Length = 90 | Episode Return = -17.612 | Episodes = 212 | Steps = 19080 | Steps Per Second = 529.287
# [Environment Loop] Episode Length = 90 | Episode Return = -11.253 | Episodes = 218 | Steps = 19620 | Steps Per Second = 499.932
# [Environment Loop] Episode Length = 90 | Episode Return = -14.905 | Episodes = 223 | Steps = 20070 | Steps Per Second = 522.437
# [Environment Loop] Episode Length = 90 | Episode Return = -29.166 | Episodes = 229 | Steps = 20610 | Steps Per Second = 546.320
# [Environment Loop] Episode Length = 90 | Episode Return = -23.800 | Episodes = 235 | Steps = 21150 | Steps Per Second = 548.251
# [Environment Loop] Episode Length = 90 | Episode Return = -18.654 | Episodes = 241 | Steps = 21690 | Steps Per Second = 548.000
# [Environment Loop] Episode Length = 90 | Episode Return = -8.569 | Episodes = 246 | Steps = 22140 | Steps Per Second = 525.801
# [Environment Loop] Episode Length = 90 | Episode Return = -28.780 | Episodes = 252 | Steps = 22680 | Steps Per Second = 539.749
# [Environment Loop] Episode Length = 90 | Episode Return = -6.354 | Episodes = 258 | Steps = 23220 | Steps Per Second = 518.622
# [Environment Loop] Episode Length = 90 | Episode Return = -26.243 | Episodes = 264 | Steps = 23760 | Steps Per Second = 302.401
# [Environment Loop] Episode Length = 90 | Episode Return = -32.126 | Episodes = 270 | Steps = 24300 | Steps Per Second = 299.559
# [Environment Loop] Episode Length = 90 | Episode Return = -9.617 | Episodes = 276 | Steps = 24840 | Steps Per Second = 288.426
# [Environment Loop] Episode Length = 90 | Episode Return = -19.236 | Episodes = 282 | Steps = 25380 | Steps Per Second = 495.936
# [Environment Loop] Episode Length = 90 | Episode Return = -46.191 | Episodes = 288 | Steps = 25920 | Steps Per Second = 543.401
# [Environment Loop] Episode Length = 90 | Episode Return = -23.722 | Episodes = 294 | Steps = 26460 | Steps Per Second = 552.894
# [Environment Loop] Episode Length = 90 | Episode Return = -19.620 | Episodes = 300 | Steps = 27000 | Steps Per Second = 545.670
# [Environment Loop] Episode Length = 90 | Episode Return = -20.156 | Episodes = 306 | Steps = 27540 | Steps Per Second = 546.454
# [Environment Loop] Episode Length = 90 | Episode Return = -6.487 | Episodes = 312 | Steps = 28080 | Steps Per Second = 545.446
# [Environment Loop] Episode Length = 90 | Episode Return = -6.552 | Episodes = 318 | Steps = 28620 | Steps Per Second = 546.832
# [Environment Loop] Episode Length = 90 | Episode Return = -21.003 | Episodes = 324 | Steps = 29160 | Steps Per Second = 481.119
# [Environment Loop] Episode Length = 90 | Episode Return = -25.232 | Episodes = 329 | Steps = 29610 | Steps Per Second = 505.850
# [Environment Loop] Episode Length = 90 | Episode Return = -31.157 | Episodes = 335 | Steps = 30150 | Steps Per Second = 494.933
# [Environment Loop] Episode Length = 90 | Episode Return = -8.351 | Episodes = 341 | Steps = 30690 | Steps Per Second = 540.983
# [Environment Loop] Episode Length = 90 | Episode Return = -31.100 | Episodes = 347 | Steps = 31230 | Steps Per Second = 549.160
# [Environment Loop] Episode Length = 90 | Episode Return = -15.893 | Episodes = 353 | Steps = 31770 | Steps Per Second = 543.873
# [Environment Loop] Episode Length = 90 | Episode Return = -5.163 | Episodes = 358 | Steps = 32220 | Steps Per Second = 293.682
# [Environment Loop] Episode Length = 90 | Episode Return = -47.959 | Episodes = 364 | Steps = 32760 | Steps Per Second = 297.617
# [Environment Loop] Episode Length = 90 | Episode Return = -11.487 | Episodes = 370 | Steps = 33300 | Steps Per Second = 294.592
# [Environment Loop] Episode Length = 90 | Episode Return = -33.819 | Episodes = 376 | Steps = 33840 | Steps Per Second = 502.937
# [Environment Loop] Episode Length = 90 | Episode Return = -14.182 | Episodes = 382 | Steps = 34380 | Steps Per Second = 468.204
# [Environment Loop] Episode Length = 90 | Episode Return = -14.505 | Episodes = 388 | Steps = 34920 | Steps Per Second = 533.306
# [Environment Loop] Episode Length = 90 | Episode Return = -24.319 | Episodes = 393 | Steps = 35370 | Steps Per Second = 532.733
# [Environment Loop] Episode Length = 90 | Episode Return = -20.318 | Episodes = 398 | Steps = 35820 | Steps Per Second = 528.443
# [Environment Loop] Episode Length = 90 | Episode Return = -6.141 | Episodes = 403 | Steps = 36270 | Steps Per Second = 526.846
# [Environment Loop] Episode Length = 90 | Episode Return = -9.374 | Episodes = 408 | Steps = 36720 | Steps Per Second = 295.856
# [Environment Loop] Episode Length = 90 | Episode Return = -18.620 | Episodes = 414 | Steps = 37260 | Steps Per Second = 290.190
# [Environment Loop] Episode Length = 90 | Episode Return = -6.720 | Episodes = 420 | Steps = 37800 | Steps Per Second = 285.836
# [Environment Loop] Episode Length = 90 | Episode Return = -20.694 | Episodes = 426 | Steps = 38340 | Steps Per Second = 537.053
# [Environment Loop] Episode Length = 90 | Episode Return = -10.686 | Episodes = 431 | Steps = 38790 | Steps Per Second = 506.096
# [Environment Loop] Episode Length = 90 | Episode Return = -15.891 | Episodes = 436 | Steps = 39240 | Steps Per Second = 534.530
# [Environment Loop] Episode Length = 90 | Episode Return = -12.730 | Episodes = 441 | Steps = 39690 | Steps Per Second = 531.612
# [Environment Loop] Episode Length = 90 | Episode Return = -5.635 | Episodes = 446 | Steps = 40140 | Steps Per Second = 504.946
# [Environment Loop] Episode Length = 90 | Episode Return = -11.730 | Episodes = 452 | Steps = 40680 | Steps Per Second = 292.000
# [Environment Loop] Episode Length = 90 | Episode Return = -10.602 | Episodes = 458 | Steps = 41220 | Steps Per Second = 299.019
# [Environment Loop] Episode Length = 90 | Episode Return = -33.910 | Episodes = 464 | Steps = 41760 | Steps Per Second = 294.281
# [Environment Loop] Episode Length = 90 | Episode Return = -7.866 | Episodes = 470 | Steps = 42300 | Steps Per Second = 530.540
# [Environment Loop] Episode Length = 90 | Episode Return = -13.493 | Episodes = 476 | Steps = 42840 | Steps Per Second = 538.937
# [Environment Loop] Episode Length = 90 | Episode Return = -0.154 | Episodes = 481 | Steps = 43290 | Steps Per Second = 533.235
# [Environment Loop] Episode Length = 90 | Episode Return = -11.267 | Episodes = 486 | Steps = 43740 | Steps Per Second = 529.275
# [Environment Loop] Episode Length = 90 | Episode Return = -18.750 | Episodes = 491 | Steps = 44190 | Steps Per Second = 534.662
# [Environment Loop] Episode Length = 90 | Episode Return = -14.455 | Episodes = 496 | Steps = 44640 | Steps Per Second = 298.634
# [Environment Loop] Episode Length = 90 | Episode Return = -12.271 | Episodes = 502 | Steps = 45180 | Steps Per Second = 291.736
# [Environment Loop] Episode Length = 90 | Episode Return = -19.699 | Episodes = 508 | Steps = 45720 | Steps Per Second = 467.520
# [Environment Loop] Episode Length = 90 | Episode Return = -14.992 | Episodes = 514 | Steps = 46260 | Steps Per Second = 300.015
# [Environment Loop] Episode Length = 90 | Episode Return = -19.569 | Episodes = 520 | Steps = 46800 | Steps Per Second = 494.870
# [Environment Loop] Episode Length = 90 | Episode Return = -9.763 | Episodes = 525 | Steps = 47250 | Steps Per Second = 497.025
# [Environment Loop] Episode Length = 90 | Episode Return = -4.496 | Episodes = 530 | Steps = 47700 | Steps Per Second = 491.256
# [Environment Loop] Episode Length = 90 | Episode Return = -14.166 | Episodes = 535 | Steps = 48150 | Steps Per Second = 496.122
# [Environment Loop] Episode Length = 90 | Episode Return = -35.315 | Episodes = 540 | Steps = 48600 | Steps Per Second = 449.382
# [Environment Loop] Episode Length = 90 | Episode Return = -3.039 | Episodes = 546 | Steps = 49140 | Steps Per Second = 282.368
# [Environment Loop] Episode Length = 90 | Episode Return = -6.617 | Episodes = 552 | Steps = 49680 | Steps Per Second = 298.110
# [Environment Loop] Episode Length = 90 | Episode Return = -10.357 | Episodes = 558 | Steps = 50220 | Steps Per Second = 296.932
# [Environment Loop] Episode Length = 90 | Episode Return = -4.873 | Episodes = 564 | Steps = 50760 | Steps Per Second = 291.093
# [Environment Loop] Episode Length = 90 | Episode Return = -15.426 | Episodes = 570 | Steps = 51300 | Steps Per Second = 526.246
# [Environment Loop] Episode Length = 90 | Episode Return = -25.506 | Episodes = 575 | Steps = 51750 | Steps Per Second = 523.026
# [Environment Loop] Episode Length = 90 | Episode Return = -14.256 | Episodes = 580 | Steps = 52200 | Steps Per Second = 521.911
# [Environment Loop] Episode Length = 90 | Episode Return = -14.838 | Episodes = 585 | Steps = 52650 | Steps Per Second = 525.538
# [Environment Loop] Episode Length = 90 | Episode Return = -33.713 | Episodes = 591 | Steps = 53190 | Steps Per Second = 521.102
# [Environment Loop] Episode Length = 90 | Episode Return = -20.545 | Episodes = 596 | Steps = 53640 | Steps Per Second = 287.181
# [Environment Loop] Episode Length = 90 | Episode Return = -9.769 | Episodes = 602 | Steps = 54180 | Steps Per Second = 296.091
# [Environment Loop] Episode Length = 90 | Episode Return = -24.110 | Episodes = 608 | Steps = 54720 | Steps Per Second = 290.076
# [Environment Loop] Episode Length = 90 | Episode Return = -34.674 | Episodes = 614 | Steps = 55260 | Steps Per Second = 491.632
# [Environment Loop] Episode Length = 90 | Episode Return = -4.998 | Episodes = 619 | Steps = 55710 | Steps Per Second = 492.296
# [Environment Loop] Episode Length = 90 | Episode Return = -8.252 | Episodes = 624 | Steps = 56160 | Steps Per Second = 503.170
# [Environment Loop] Episode Length = 90 | Episode Return = -22.028 | Episodes = 629 | Steps = 56610 | Steps Per Second = 500.686
# [Environment Loop] Episode Length = 90 | Episode Return = -6.932 | Episodes = 634 | Steps = 57060 | Steps Per Second = 513.335
# [Environment Loop] Episode Length = 90 | Episode Return = -14.842 | Episodes = 640 | Steps = 57600 | Steps Per Second = 285.122
# [Environment Loop] Episode Length = 90 | Episode Return = -21.076 | Episodes = 646 | Steps = 58140 | Steps Per Second = 296.633
# [Environment Loop] Episode Length = 90 | Episode Return = -15.413 | Episodes = 652 | Steps = 58680 | Steps Per Second = 289.402
# [Environment Loop] Episode Length = 90 | Episode Return = -16.814 | Episodes = 658 | Steps = 59220 | Steps Per Second = 284.415
# [Environment Loop] Episode Length = 90 | Episode Return = -15.711 | Episodes = 664 | Steps = 59760 | Steps Per Second = 530.016
# [Environment Loop] Episode Length = 90 | Episode Return = -11.577 | Episodes = 670 | Steps = 60300 | Steps Per Second = 535.659
# [Environment Loop] Episode Length = 90 | Episode Return = -6.142 | Episodes = 675 | Steps = 60750 | Steps Per Second = 509.847
# [Environment Loop] Episode Length = 90 | Episode Return = -20.179 | Episodes = 680 | Steps = 61200 | Steps Per Second = 509.798
# [Environment Loop] Episode Length = 90 | Episode Return = -24.832 | Episodes = 685 | Steps = 61650 | Steps Per Second = 512.597
# [Environment Loop] Episode Length = 90 | Episode Return = -11.536 | Episodes = 690 | Steps = 62100 | Steps Per Second = 288.224
# [Environment Loop] Episode Length = 90 | Episode Return = -25.565 | Episodes = 696 | Steps = 62640 | Steps Per Second = 290.895
# [Environment Loop] Episode Length = 90 | Episode Return = -17.180 | Episodes = 702 | Steps = 63180 | Steps Per Second = 286.869
# [Environment Loop] Episode Length = 90 | Episode Return = -11.536 | Episodes = 708 | Steps = 63720 | Steps Per Second = 419.693
# [Environment Loop] Episode Length = 90 | Episode Return = -6.830 | Episodes = 713 | Steps = 64170 | Steps Per Second = 433.213
# [Environment Loop] Episode Length = 90 | Episode Return = -25.744 | Episodes = 718 | Steps = 64620 | Steps Per Second = 450.254
# [Environment Loop] Episode Length = 90 | Episode Return = -12.539 | Episodes = 723 | Steps = 65070 | Steps Per Second = 442.969
# [Environment Loop] Episode Length = 90 | Episode Return = -11.414 | Episodes = 728 | Steps = 65520 | Steps Per Second = 451.085
# [Environment Loop] Episode Length = 90 | Episode Return = -14.837 | Episodes = 734 | Steps = 66060 | Steps Per Second = 280.727
# [Environment Loop] Episode Length = 90 | Episode Return = -21.655 | Episodes = 740 | Steps = 66600 | Steps Per Second = 284.612
# [Environment Loop] Episode Length = 90 | Episode Return = -13.574 | Episodes = 746 | Steps = 67140 | Steps Per Second = 272.641
# [Environment Loop] Episode Length = 90 | Episode Return = -7.632 | Episodes = 752 | Steps = 67680 | Steps Per Second = 290.426
# [Environment Loop] Episode Length = 90 | Episode Return = -17.375 | Episodes = 758 | Steps = 68220 | Steps Per Second = 517.156
# [Environment Loop] Episode Length = 90 | Episode Return = -18.960 | Episodes = 763 | Steps = 68670 | Steps Per Second = 522.413
# [Environment Loop] Episode Length = 90 | Episode Return = -2.618 | Episodes = 768 | Steps = 69120 | Steps Per Second = 520.550
# [Environment Loop] Episode Length = 90 | Episode Return = -8.785 | Episodes = 773 | Steps = 69570 | Steps Per Second = 524.857
# [Environment Loop] Episode Length = 90 | Episode Return = -10.691 | Episodes = 778 | Steps = 70020 | Steps Per Second = 503.865
# [Environment Loop] Episode Length = 90 | Episode Return = -16.606 | Episodes = 784 | Steps = 70560 | Steps Per Second = 284.500
# [Environment Loop] Episode Length = 90 | Episode Return = -37.050 | Episodes = 790 | Steps = 71100 | Steps Per Second = 286.576
# [Environment Loop] Episode Length = 90 | Episode Return = -15.229 | Episodes = 796 | Steps = 71640 | Steps Per Second = 293.001
# [Environment Loop] Episode Length = 90 | Episode Return = -24.856 | Episodes = 802 | Steps = 72180 | Steps Per Second = 468.746
# [Environment Loop] Episode Length = 90 | Episode Return = -16.015 | Episodes = 808 | Steps = 72720 | Steps Per Second = 521.662
# [Environment Loop] Episode Length = 90 | Episode Return = -14.333 | Episodes = 813 | Steps = 73170 | Steps Per Second = 534.901
# [Environment Loop] Episode Length = 90 | Episode Return = -4.962 | Episodes = 819 | Steps = 73710 | Steps Per Second = 519.929
# [Environment Loop] Episode Length = 90 | Episode Return = -8.497 | Episodes = 824 | Steps = 74160 | Steps Per Second = 519.027
# [Environment Loop] Episode Length = 90 | Episode Return = -4.338 | Episodes = 829 | Steps = 74610 | Steps Per Second = 525.177
# [Environment Loop] Episode Length = 90 | Episode Return = -5.702 | Episodes = 834 | Steps = 75060 | Steps Per Second = 277.330
# [Environment Loop] Episode Length = 90 | Episode Return = -11.533 | Episodes = 840 | Steps = 75600 | Steps Per Second = 288.221
# [Environment Loop] Episode Length = 90 | Episode Return = -28.751 | Episodes = 846 | Steps = 76140 | Steps Per Second = 293.894
# [Environment Loop] Episode Length = 90 | Episode Return = -16.763 | Episodes = 852 | Steps = 76680 | Steps Per Second = 528.220
# [Environment Loop] Episode Length = 90 | Episode Return = -37.332 | Episodes = 857 | Steps = 77130 | Steps Per Second = 489.681
# [Environment Loop] Episode Length = 90 | Episode Return = -17.090 | Episodes = 862 | Steps = 77580 | Steps Per Second = 512.893
# [Environment Loop] Episode Length = 90 | Episode Return = -9.450 | Episodes = 867 | Steps = 78030 | Steps Per Second = 514.836
# [Environment Loop] Episode Length = 90 | Episode Return = -23.018 | Episodes = 872 | Steps = 78480 | Steps Per Second = 482.532
# [Environment Loop] Episode Length = 90 | Episode Return = -8.250 | Episodes = 878 | Steps = 79020 | Steps Per Second = 286.190
# [Environment Loop] Episode Length = 90 | Episode Return = -8.468 | Episodes = 884 | Steps = 79560 | Steps Per Second = 281.717
# [Environment Loop] Episode Length = 90 | Episode Return = -26.786 | Episodes = 890 | Steps = 80100 | Steps Per Second = 280.776
# [Environment Loop] Episode Length = 90 | Episode Return = -16.551 | Episodes = 896 | Steps = 80640 | Steps Per Second = 292.395
# [Environment Loop] Episode Length = 90 | Episode Return = -5.862 | Episodes = 902 | Steps = 81180 | Steps Per Second = 523.576
# [Environment Loop] Episode Length = 90 | Episode Return = -17.172 | Episodes = 907 | Steps = 81630 | Steps Per Second = 519.720
# [Environment Loop] Episode Length = 90 | Episode Return = -18.910 | Episodes = 912 | Steps = 82080 | Steps Per Second = 518.384
# [Environment Loop] Episode Length = 90 | Episode Return = -46.043 | Episodes = 917 | Steps = 82530 | Steps Per Second = 515.453
# [Environment Loop] Episode Length = 90 | Episode Return = -5.893 | Episodes = 923 | Steps = 83070 | Steps Per Second = 516.128
# [Environment Loop] Episode Length = 90 | Episode Return = -11.511 | Episodes = 928 | Steps = 83520 | Steps Per Second = 294.402
# [Environment Loop] Episode Length = 90 | Episode Return = -17.689 | Episodes = 934 | Steps = 84060 | Steps Per Second = 291.386
# [Environment Loop] Episode Length = 90 | Episode Return = -11.421 | Episodes = 940 | Steps = 84600 | Steps Per Second = 283.418
# [Environment Loop] Episode Length = 90 | Episode Return = -2.790 | Episodes = 946 | Steps = 85140 | Steps Per Second = 487.616
# [Environment Loop] Episode Length = 90 | Episode Return = -14.900 | Episodes = 951 | Steps = 85590 | Steps Per Second = 488.999
# [Environment Loop] Episode Length = 90 | Episode Return = -20.884 | Episodes = 956 | Steps = 86040 | Steps Per Second = 478.042
# [Environment Loop] Episode Length = 90 | Episode Return = -17.183 | Episodes = 961 | Steps = 86490 | Steps Per Second = 482.790
# [Environment Loop] Episode Length = 90 | Episode Return = -15.847 | Episodes = 966 | Steps = 86940 | Steps Per Second = 483.990
# [Environment Loop] Episode Length = 90 | Episode Return = -20.364 | Episodes = 972 | Steps = 87480 | Steps Per Second = 421.576
# [Environment Loop] Episode Length = 90 | Episode Return = -14.942 | Episodes = 978 | Steps = 88020 | Steps Per Second = 294.653
# [Environment Loop] Episode Length = 90 | Episode Return = -11.213 | Episodes = 984 | Steps = 88560 | Steps Per Second = 290.325
# [Environment Loop] Episode Length = 90 | Episode Return = -26.564 | Episodes = 990 | Steps = 89100 | Steps Per Second = 289.463
# [Environment Loop] Episode Length = 90 | Episode Return = -17.856 | Episodes = 996 | Steps = 89640 | Steps Per Second = 517.110

# %%
d4pg_bot.get_predictor()._update_progress_figures()
status = d4pg_bot.get_predictor()._progress_measures
print("D4PG Bot PnL mean-var %s" % str(status['mean-var']))
print("D4PG Bot PnL mean %s" % str(status['pnl_mean']))
print("D4PG Bot PnL std %s" % str(status['pnl_std']))
print("D4PG Bot 95VaR %s" % status['pnl_95VaR'])
print("D4PG Bot 99VaR %s" % status['pnl_99VaR'])
print("D4PG Bot 95CVaR %s" % status['pnl_95CVaR'])
print("D4PG Bot 99CVaR %s" % status['pnl_99CVaR'])
d4pg_hedge_perf = pd.read_csv(f'{model_path}logs/d4pg_predictor/performance/logs.csv')
d4pg_hedge_pnl_list = d4pg_hedge_perf[d4pg_hedge_perf.type=='pnl'].drop(['path_num','type'], axis=1).sum(axis=1).values
np.save(f'{model_path}d4pg_hedge_pnl_measures.npy', d4pg_hedge_pnl_list)

status_dic = {}

for k in status.keys():
  status_dic[k] = [status[k]]

pd.DataFrame.from_dict(status_dic, orient="index", columns=["drl"]).to_csv(f'{model_path}drl_pnl_stat.csv')
# Out:
# D4PG Bot PnL mean-var -28.579930217166762
# D4PG Bot PnL mean -15.711697630174859
# D4PG Bot PnL std 8.578821724661267
# D4PG Bot 95VaR -32.13091397220851
# D4PG Bot 99VaR -42.396176183178866
# D4PG Bot 95CVaR -38.15350273776123
# D4PG Bot 99CVaR -47.32298405718866

# %%
#@title GreekHedge Bot
market.set_pred_mode(True)
market.set_pred_episodes(num_prediction_episodes)
spec = specs.make_environment_spec(market)

# Construct the agent.
agent = GreekHedgeBot(
    portfolio=portfolio,
    use_bs_delta=True,
    environment_spec=spec,
    pred_dir = model_path
)
# Try running the environment loop. We have no assertions here because all
# we care about is that the agent runs without raising any errors.
loop = acme.EnvironmentLoop(market, agent)
loop.run(num_episodes=market.get_pred_episodes())
agent.get_predictor()._update_progress_figures()
status = agent.get_predictor()._progress_measures
print("Greek Bot PnL mean-var %s" % str(status['mean-var']))
print("Greek Bot PnL mean %s" % str(status['pnl_mean']))
print("Greek Bot PnL std %s" % str(status['pnl_std']))
print("Greek Bot 95VaR %s" % status['pnl_95VaR'])
print("Greek Bot 99VaR %s" % status['pnl_99VaR'])
print("Greek Bot 95CVaR %s" % status['pnl_95CVaR'])
print("Greek Bot 99CVaR %s" % status['pnl_99CVaR'])
greek_hedge_perf = pd.read_csv(f'{model_path}logs/greek_hedge_predictor/performance/logs.csv')
greek_hedge_pnl_list = greek_hedge_perf[greek_hedge_perf.type=='pnl'].drop(['path_num','type'], axis=1).sum(axis=1).values
np.save(f'{model_path}greek_hedge_pnl_measures.npy', greek_hedge_pnl_list)

status_dic = {}

for k in status.keys():
  status_dic[k] = [status[k]]

pd.DataFrame.from_dict(status_dic, orient="index", columns=["greek"]).to_csv(f'{model_path}greek_pnl_stat.csv')
# Out:
# [Environment Loop] Episode Length = 90 | Episode Return = -24.736 | Episodes = 12 | Steps = 1080 | Steps Per Second = 1480.000
# [Environment Loop] Episode Length = 90 | Episode Return = -30.155 | Episodes = 24 | Steps = 2160 | Steps Per Second = 1478.783
# [Environment Loop] Episode Length = 90 | Episode Return = -6.496 | Episodes = 37 | Steps = 3330 | Steps Per Second = 1448.359
# [Environment Loop] Episode Length = 90 | Episode Return = -20.680 | Episodes = 49 | Steps = 4410 | Steps Per Second = 1468.531
# [Environment Loop] Episode Length = 90 | Episode Return = -18.568 | Episodes = 61 | Steps = 5490 | Steps Per Second = 1306.524
# [Environment Loop] Episode Length = 90 | Episode Return = -16.975 | Episodes = 73 | Steps = 6570 | Steps Per Second = 463.562
# [Environment Loop] Episode Length = 90 | Episode Return = -10.922 | Episodes = 86 | Steps = 7740 | Steps Per Second = 453.628
# [Environment Loop] Episode Length = 90 | Episode Return = -15.794 | Episodes = 99 | Steps = 8910 | Steps Per Second = 429.300
# [Environment Loop] Episode Length = 90 | Episode Return = -20.326 | Episodes = 112 | Steps = 10080 | Steps Per Second = 462.553
# [Environment Loop] Episode Length = 90 | Episode Return = -17.874 | Episodes = 125 | Steps = 11250 | Steps Per Second = 583.433
# [Environment Loop] Episode Length = 90 | Episode Return = -18.629 | Episodes = 137 | Steps = 12330 | Steps Per Second = 464.270
# [Environment Loop] Episode Length = 90 | Episode Return = -13.334 | Episodes = 150 | Steps = 13500 | Steps Per Second = 460.654
# [Environment Loop] Episode Length = 90 | Episode Return = -13.334 | Episodes = 163 | Steps = 14670 | Steps Per Second = 445.779
# [Environment Loop] Episode Length = 90 | Episode Return = -13.849 | Episodes = 176 | Steps = 15840 | Steps Per Second = 455.804
# [Environment Loop] Episode Length = 90 | Episode Return = -9.565 | Episodes = 189 | Steps = 17010 | Steps Per Second = 459.739
# [Environment Loop] Episode Length = 90 | Episode Return = -26.173 | Episodes = 202 | Steps = 18180 | Steps Per Second = 467.603
# [Environment Loop] Episode Length = 90 | Episode Return = -14.501 | Episodes = 215 | Steps = 19350 | Steps Per Second = 451.483
# [Environment Loop] Episode Length = 90 | Episode Return = -15.351 | Episodes = 228 | Steps = 20520 | Steps Per Second = 456.705
# [Environment Loop] Episode Length = 90 | Episode Return = -25.476 | Episodes = 241 | Steps = 21690 | Steps Per Second = 451.529
# [Environment Loop] Episode Length = 90 | Episode Return = -28.262 | Episodes = 254 | Steps = 22860 | Steps Per Second = 459.587
# [Environment Loop] Episode Length = 90 | Episode Return = -6.417 | Episodes = 267 | Steps = 24030 | Steps Per Second = 453.128
# [Environment Loop] Episode Length = 90 | Episode Return = -22.954 | Episodes = 281 | Steps = 25290 | Steps Per Second = 573.334
# [Environment Loop] Episode Length = 90 | Episode Return = -29.784 | Episodes = 294 | Steps = 26460 | Steps Per Second = 465.340
# [Environment Loop] Episode Length = 90 | Episode Return = -19.513 | Episodes = 307 | Steps = 27630 | Steps Per Second = 455.709
# [Environment Loop] Episode Length = 90 | Episode Return = -38.641 | Episodes = 321 | Steps = 28890 | Steps Per Second = 453.948
# [Environment Loop] Episode Length = 90 | Episode Return = -14.837 | Episodes = 334 | Steps = 30060 | Steps Per Second = 446.338
# [Environment Loop] Episode Length = 90 | Episode Return = -23.979 | Episodes = 348 | Steps = 31320 | Steps Per Second = 601.099
# [Environment Loop] Episode Length = 90 | Episode Return = -4.520 | Episodes = 361 | Steps = 32490 | Steps Per Second = 423.019
# [Environment Loop] Episode Length = 90 | Episode Return = -50.798 | Episodes = 374 | Steps = 33660 | Steps Per Second = 433.121
# [Environment Loop] Episode Length = 90 | Episode Return = -28.002 | Episodes = 386 | Steps = 34740 | Steps Per Second = 1360.035
# [Environment Loop] Episode Length = 90 | Episode Return = -25.702 | Episodes = 397 | Steps = 35730 | Steps Per Second = 1327.377
# [Environment Loop] Episode Length = 90 | Episode Return = -12.241 | Episodes = 408 | Steps = 36720 | Steps Per Second = 413.635
# [Environment Loop] Episode Length = 90 | Episode Return = -11.329 | Episodes = 421 | Steps = 37890 | Steps Per Second = 434.098
# [Environment Loop] Episode Length = 90 | Episode Return = -14.407 | Episodes = 433 | Steps = 38970 | Steps Per Second = 1284.263
# [Environment Loop] Episode Length = 90 | Episode Return = -11.009 | Episodes = 444 | Steps = 39960 | Steps Per Second = 1326.817
# [Environment Loop] Episode Length = 90 | Episode Return = -10.078 | Episodes = 455 | Steps = 40950 | Steps Per Second = 446.065
# [Environment Loop] Episode Length = 90 | Episode Return = -35.226 | Episodes = 467 | Steps = 42030 | Steps Per Second = 1272.282
# [Environment Loop] Episode Length = 90 | Episode Return = -16.094 | Episodes = 477 | Steps = 42930 | Steps Per Second = 1286.947
# [Environment Loop] Episode Length = 90 | Episode Return = -30.084 | Episodes = 488 | Steps = 43920 | Steps Per Second = 404.085
# [Environment Loop] Episode Length = 90 | Episode Return = -10.238 | Episodes = 500 | Steps = 45000 | Steps Per Second = 1287.847
# [Environment Loop] Episode Length = 90 | Episode Return = -26.611 | Episodes = 510 | Steps = 45900 | Steps Per Second = 1212.768
# [Environment Loop] Episode Length = 90 | Episode Return = -23.295 | Episodes = 522 | Steps = 46980 | Steps Per Second = 446.109
# [Environment Loop] Episode Length = 90 | Episode Return = -4.552 | Episodes = 534 | Steps = 48060 | Steps Per Second = 1268.571
# [Environment Loop] Episode Length = 90 | Episode Return = -19.286 | Episodes = 545 | Steps = 49050 | Steps Per Second = 1279.345
# [Environment Loop] Episode Length = 90 | Episode Return = -20.331 | Episodes = 556 | Steps = 50040 | Steps Per Second = 1245.307
# [Environment Loop] Episode Length = 90 | Episode Return = -22.614 | Episodes = 569 | Steps = 51210 | Steps Per Second = 439.765
# [Environment Loop] Episode Length = 90 | Episode Return = -19.497 | Episodes = 581 | Steps = 52290 | Steps Per Second = 1255.938
# [Environment Loop] Episode Length = 90 | Episode Return = -31.563 | Episodes = 591 | Steps = 53190 | Steps Per Second = 1226.995
# [Environment Loop] Episode Length = 90 | Episode Return = -12.402 | Episodes = 602 | Steps = 54180 | Steps Per Second = 430.093
# [Environment Loop] Episode Length = 90 | Episode Return = -39.491 | Episodes = 614 | Steps = 55260 | Steps Per Second = 1261.382
# [Environment Loop] Episode Length = 90 | Episode Return = -15.381 | Episodes = 625 | Steps = 56250 | Steps Per Second = 1244.691
# [Environment Loop] Episode Length = 90 | Episode Return = -9.146 | Episodes = 636 | Steps = 57240 | Steps Per Second = 435.305
# [Environment Loop] Episode Length = 90 | Episode Return = -15.751 | Episodes = 648 | Steps = 58320 | Steps Per Second = 1253.145
# [Environment Loop] Episode Length = 90 | Episode Return = -24.460 | Episodes = 658 | Steps = 59220 | Steps Per Second = 1277.133
# [Environment Loop] Episode Length = 90 | Episode Return = -24.317 | Episodes = 669 | Steps = 60210 | Steps Per Second = 442.437
# [Environment Loop] Episode Length = 90 | Episode Return = -10.817 | Episodes = 681 | Steps = 61290 | Steps Per Second = 1256.164
# [Environment Loop] Episode Length = 90 | Episode Return = -8.282 | Episodes = 692 | Steps = 62280 | Steps Per Second = 1213.755
# [Environment Loop] Episode Length = 90 | Episode Return = -16.139 | Episodes = 703 | Steps = 63270 | Steps Per Second = 421.770
# [Environment Loop] Episode Length = 90 | Episode Return = -20.669 | Episodes = 715 | Steps = 64350 | Steps Per Second = 1267.987
# [Environment Loop] Episode Length = 90 | Episode Return = -15.988 | Episodes = 725 | Steps = 65250 | Steps Per Second = 1267.808
# [Environment Loop] Episode Length = 90 | Episode Return = -19.598 | Episodes = 736 | Steps = 66240 | Steps Per Second = 429.723
# [Environment Loop] Episode Length = 90 | Episode Return = -18.303 | Episodes = 748 | Steps = 67320 | Steps Per Second = 1138.529
# [Environment Loop] Episode Length = 90 | Episode Return = -22.157 | Episodes = 758 | Steps = 68220 | Steps Per Second = 1121.858
# [Environment Loop] Episode Length = 90 | Episode Return = -20.397 | Episodes = 770 | Steps = 69300 | Steps Per Second = 587.418
# [Environment Loop] Episode Length = 90 | Episode Return = -17.216 | Episodes = 782 | Steps = 70380 | Steps Per Second = 1106.505
# [Environment Loop] Episode Length = 90 | Episode Return = -19.556 | Episodes = 792 | Steps = 71280 | Steps Per Second = 1079.553
# [Environment Loop] Episode Length = 90 | Episode Return = -10.946 | Episodes = 803 | Steps = 72270 | Steps Per Second = 436.191
# [Environment Loop] Episode Length = 90 | Episode Return = -11.041 | Episodes = 815 | Steps = 73350 | Steps Per Second = 1227.047
# [Environment Loop] Episode Length = 90 | Episode Return = -29.213 | Episodes = 825 | Steps = 74250 | Steps Per Second = 1224.563
# [Environment Loop] Episode Length = 90 | Episode Return = -21.666 | Episodes = 837 | Steps = 75330 | Steps Per Second = 606.820
# [Environment Loop] Episode Length = 90 | Episode Return = -21.374 | Episodes = 850 | Steps = 76500 | Steps Per Second = 426.877
# [Environment Loop] Episode Length = 90 | Episode Return = -20.964 | Episodes = 862 | Steps = 77580 | Steps Per Second = 1236.330
# [Environment Loop] Episode Length = 90 | Episode Return = -21.002 | Episodes = 872 | Steps = 78480 | Steps Per Second = 1225.955
# [Environment Loop] Episode Length = 90 | Episode Return = -20.580 | Episodes = 883 | Steps = 79470 | Steps Per Second = 437.970
# [Environment Loop] Episode Length = 90 | Episode Return = -17.803 | Episodes = 895 | Steps = 80550 | Steps Per Second = 1216.747
# [Environment Loop] Episode Length = 90 | Episode Return = -24.785 | Episodes = 906 | Steps = 81540 | Steps Per Second = 1194.713
# [Environment Loop] Episode Length = 90 | Episode Return = -50.771 | Episodes = 917 | Steps = 82530 | Steps Per Second = 430.894
# [Environment Loop] Episode Length = 90 | Episode Return = -20.127 | Episodes = 929 | Steps = 83610 | Steps Per Second = 1205.314
# [Environment Loop] Episode Length = 90 | Episode Return = -7.362 | Episodes = 939 | Steps = 84510 | Steps Per Second = 1121.169
# [Environment Loop] Episode Length = 90 | Episode Return = -3.977 | Episodes = 950 | Steps = 85500 | Steps Per Second = 428.739
# [Environment Loop] Episode Length = 90 | Episode Return = -18.503 | Episodes = 962 | Steps = 86580 | Steps Per Second = 1095.401
# [Environment Loop] Episode Length = 90 | Episode Return = -19.779 | Episodes = 973 | Steps = 87570 | Steps Per Second = 1189.098
# [Environment Loop] Episode Length = 90 | Episode Return = -15.106 | Episodes = 984 | Steps = 88560 | Steps Per Second = 433.732
# [Environment Loop] Episode Length = 90 | Episode Return = -18.226 | Episodes = 996 | Steps = 89640 | Steps Per Second = 1193.062
# Greek Bot PnL mean-var -31.252559930563706
# Greek Bot PnL mean -18.246332697705068
# Greek Bot PnL std 8.670818155239091
# Greek Bot 95VaR -34.409878664556885
# Greek Bot 99VaR -43.537621196263935
# Greek Bot 95CVaR -39.94883095412544
# Greek Bot 99CVaR -48.38786138250725

# %%
#@title Plot PnL Distribution
greek_hedge_pnl_list = np.load(f'{model_path}greek_hedge_pnl_measures.npy')
d4pg_hedge_pnl_list = np.load(f'{model_path}d4pg_hedge_pnl_measures.npy')
plt.hist(greek_hedge_pnl_list, bins=50, alpha=0.5, label='Greek Hedge', density=True)
plt.hist(d4pg_hedge_pnl_list, bins=50, alpha=0.5, label='DRL Hedge', density=True)
plt.legend(loc='upper left')
plt.savefig(f'{model_path}pnl_dist.png')
plt.show()

# %%
def path_plot(delta_pnl, d4pg_pnl, delta_action, d4pg_action, hedging_price, derivative_price, figure_name):
  hedging_dim = hedging_price.shape[0]
  derivative_dim = derivative_price.shape[0]
  step_dim = hedging_price.shape[1]
  d4pg_cum_pnl = np.cumsum(pd.to_numeric(d4pg_pnl))
  delta_cum_pnl = np.cumsum(pd.to_numeric(delta_pnl))
  d4pg_cum_holding = np.cumsum(d4pg_action, axis=1) + initial_stock_holding
  delta_cum_holding = np.cumsum(delta_action, axis=1) + initial_stock_holding

  num_sub_plts = 2+2*hedging_dim
  fig, axs = plt.subplots(num_sub_plts, 1,figsize=(num_sub_plts*10,10))
  for i in range(hedging_dim):
    axs[0].plot(hedging_price[i,:], label=f'Hedging Instrument {i}')
  axs[0].grid(True)
  axs[0].set_ylabel('Hedging Instrument Prices')
  ax2 = axs[0].twinx()  # instantiate a second axes that shares the same x-axis
  ax2.set_ylabel('Derivative Prices') 
  for i in range(derivative_dim): 
    ax2.plot(derivative_price[i,:], label=f'Liability {i}')
  axs[0].legend(loc='upper left')
  ax2.legend(loc='lower left')

  for i in range(hedging_dim):
    axs[1+i*2].bar(range(0, step_dim), d4pg_action[i,:], alpha=0.5, label='D4PG bot hedging action')
    axs[1+i*2].bar(range(0, step_dim), delta_action[i,:], alpha=0.5, label='Delta bot hedging action')
    axs[1+i*2].legend(loc='upper left')
    axs[1+i*2].set_ylabel(f'Hedging {i} Action')

    axs[2+i*2].bar(range(0, step_dim), d4pg_cum_holding[i,:], alpha=0.5, label='D4PG bot hedging holding')
    axs[2+i*2].bar(range(0, step_dim), delta_cum_holding[i,:], alpha=0.5, label='Delta bot hedging holding')
    axs[2+i*2].legend(loc='upper left')
    axs[2+i*2].set_ylabel(f'Hedging {i} Holding')

  axs[1+2*hedging_dim].plot(d4pg_cum_pnl, label='D4PG bot accumulative P&L')
  axs[1+2*hedging_dim].plot(delta_cum_pnl, label='Delta bot accumulative P&L')
  axs[1+2*hedging_dim].grid(True)
  axs[1+2*hedging_dim].legend(loc='upper left')
  axs[1+2*hedging_dim].set_xlabel('time')

  fig.tight_layout()
  plt.savefig(f'{model_path}price_action_path_{figure_name}.png')
  plt.show()

# %% [markdown]
# # Covid19 Stress Testing

# %%
#@title Stress Testing
scenario_name = "Covid19" #@param {type:"string"}
market.load_scenario(scenario_name)
loop = acme.EnvironmentLoop(market, agent)
loop.run(num_episodes=market.get_pred_episodes())
market.load_scenario(scenario_name)
loop = acme.EnvironmentLoop(market, d4pg_bot)
loop.run(num_episodes=market.get_pred_episodes())

# %%
greek_predictor = agent.get_predictor()
d4pg_predictor = d4pg_bot.get_predictor()
greek_stress_pnl = greek_predictor.get_episode_pnl_path()
greek_hedging_price = greek_predictor.get_episode_hedging_price()
greek_derivative_price = greek_predictor.get_episode_derivative_price()
greek_actions = greek_predictor.get_episode_action()
d4pg_stress_pnl = d4pg_predictor.get_episode_pnl_path()
d4pg_actions = d4pg_predictor.get_episode_action()
d4pg_hedging_price = d4pg_predictor.get_episode_hedging_price()
d4pg_derivative_price = d4pg_predictor.get_episode_derivative_price()
path_plot(greek_stress_pnl, d4pg_stress_pnl, greek_actions, d4pg_actions, greek_hedging_price, greek_derivative_price, scenario_name)

# %%
print(f"Greek Hedging P&L: {np.sum(greek_stress_pnl)}")
print(f"D4PG Hedging P&L: {np.sum(d4pg_stress_pnl)}")
# Out:
# Greek Hedging P&L: -26.535007901489735
# D4PG Hedging P&L: -25.154358739964664
